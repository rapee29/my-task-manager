# %% [markdown]
# Lab 5.2 : Course Enrollment & Collaboration (Set Focus)

# %%
python_students = {"S001", "S003", "S005", "S007", "S009"}
java_students = {"S002", "S003", "S006", "S007", "S010"}

both_courses = python_students.intersection(java_students)
print("Students in both Python and Java:")
print(both_courses)

all_students = python_students.union(java_students)
print("\nAll unique students:")
print(all_students)

python_only = python_students.difference(java_students)
print("\nStudents only in Python:")
print(python_only)

one_course = python_students.symmetric_difference(java_students)
print("\nStudents in only one course:")
print(one_course)

all_students_list = ["S001", "S003", "S005", "S001", "S002"]

print("\nOriginal List:")
print(all_students_list)

unique_students = list(set(all_students_list))

print("Unique List:")
print(unique_students)
# Out:
# Students in both Python and Java:
# {'S003', 'S007'}
#
# All unique students:
# {'S009', 'S006', 'S010', 'S001', 'S002', 'S005', 'S003', 'S007'}
#
# Students only in Python:
# {'S005', 'S009', 'S001'}
#
# Students in only one course:
# {'S001', 'S009', 'S006', 'S010', 'S005', 'S002'}
#
# Original List:
# ['S001', 'S003', 'S005', 'S001', 'S002']
# Unique List:
# ['S005', 'S003', 'S001', 'S002']
