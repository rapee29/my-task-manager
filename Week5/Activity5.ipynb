# %% [markdown]
# # Activity 5.1 : Real-World Applications of Dictionaries and Sets

# %% [markdown]
# 1. Where would you use a dictionary in a game?

# %% [markdown]
# Answer:
# A dictionary can store player information, inventory, or character stats.

# %% [markdown]
# 2. How could a dictionary represent product data in an online store?

# %% [markdown]
# Answer:
# A dictionary can use the product ID as the key and store product information such as name, price, and stock as values. This allows products to be searched quickly.

# %% [markdown]
# 3. When would a set be useful in managing user permissions or tags?

# %% [markdown]
# Answer:
# A set is useful for storing user permissions or hashtags because it automatically removes duplicate values and allows fast membership checking.

# %% [markdown]
# 4. Can you think of a scenario where you'd need to quickly check if an item exists in a large collection?

# %% [markdown]
# Answer:
# A set can store blocked IP addresses or registered users. It allows fast checking to determine whether an item exists.

# %% [markdown]
# # 5.2 : Word Frequency Counter (Dictionary)

# %%
sentence = input("Enter a sentence: ")

sentence = sentence.lower()

for ch in ",.!?":
    sentence = sentence.replace(ch, "")

words = sentence.split()

word_counts = {}

for word in words:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

print("\nWord Frequency:")
for word, count in word_counts.items():
    print(f"{word}: {count}")
# Out:
# Enter a sentence: Python is fun
#
# Word Frequency:
# python: 1
# is: 1
# fun: 1
