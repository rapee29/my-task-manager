# %% [markdown]
# Part 1: Countdown Timer

# %%
count = int(input("Enter the starting number for the countdown: "))

while count >= 0:
    print(count)
    count -= 1

print("Blast off!")
# Out:
# Enter the starting number for the countdown: 3
# 3
# 2
# 1
# 0
# Blast off!

# %% [markdown]
# Part 2: Simple Guessing Game

# %%
secret_number = 42

while True:
    guess = int(input("Guess the secret number: "))

    if guess < secret_number:
        print("Too low! Try again.")

    elif guess > secret_number:
        print("Too high! Try again.")

    else:
        print("Congratulations! You guessed it!")
        break
# Out:
# Guess the secret number: 5
# Too low! Try again.
# Guess the secret number: 42
# Congratulations! You guessed it!
